# %%
import numpy as np

# %%
iframe = np.load("gops/gop_0001/iframe_rgb.npy")
print(iframe.shape)
# Out:
# (1080, 1920, 3)

# %%
iframe[1000,:,:]
# Out:
# array([[30, 30, 25],
#        [31, 31, 26],
#        [33, 31, 27],
#        ...,
#        [ 3, 33, 14],
#        [ 9, 34, 16],
#        [10, 35, 17]], shape=(1920, 3), dtype=uint8)
